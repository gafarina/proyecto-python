# %%
import pandas as pd

# %%
base_fomo = pd.read_parquet(r"C:\datos_proyecto\Ranking_fear\fmp_prices_fear.parquet")

# %%
base_fomo.columns
# Out:
# Index(['symbol', 'date', 'open', 'high', 'low', 'close', 'volume', 'change',
#        'changePercent', 'vwap', 'ticker', 'PANIC_SCORE'],
#       dtype='str')

# %%
base_fomo.sort_values(['PANIC_SCORE'],ascending=False).head(40)
# Out:
#        symbol       date    open      high       low    close     volume  \
# 17955    AMRN 2022-05-05   29.40   29.6000   26.8000   27.000    1131535
# 17954    AMRN 2022-05-04   37.00   38.2000   29.0000   31.200    1990975
# 184998     LK 2020-04-03    7.05    7.3500    5.2800    5.380   95299981
# 264639   QUBT 2019-07-17    3.50    3.5000    3.0000    3.000       2400
# 363229   WULF 2022-03-04    7.80    8.4100    5.9400    6.000     634600
# 264762   QUBT 2020-01-10    2.75    2.7500    1.9000    1.900       2700
# 264673   QUBT 2019-09-04    3.30    3.9000    3.2000    3.200       7100
# 203265    MPW 2024-01-08    3.48    3.6500    3.3800    3.390   52094300
# 7200      ACB 2022-05-27   22.70   22.8000   16.2000   16.800   11052708
# 258437   PYPL 2026-02-03   42.89   43.7000   41.4300   41.700  141690600
# 192790   LYFT 2023-02-10   11.15   11.2200   10.2300   10.310  146014600
# 296980   SNAP 2021-10-22   58.75   60.7800   55.0300   55.140  153617453
# ...
